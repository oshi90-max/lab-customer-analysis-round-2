# %%
import pandas as pd
import numpy as np

file = pd.read_csv('marketing_customer_analysis.csv')
column_names = file.columns

file.shape
file
# Out:
#        Unnamed: 0 Customer       State  Customer Lifetime Value Response  \
# 0               0  DK49336     Arizona              4809.216960       No
# 1               1  KX64629  California              2228.525238       No
# 2               2  LZ68649  Washington             14947.917300       No
# 3               3  XL78013      Oregon             22332.439460      Yes
# 4               4  QA50777      Oregon              9025.067525       No
# ...           ...      ...         ...                      ...      ...
# 10905       10905  FE99816      Nevada             15563.369440       No
# 10906       10906  KX53892      Oregon              5259.444853       No
# 10907       10907  TL39050     Arizona             23893.304100       No
# 10908       10908  WA60547  California             11971.977650       No
# 10909       10909  IV32877         NaN              6857.519928      NaN
#
#        Coverage Education Effective To Date EmploymentStatus Gender  ...  \
# ...

# %%
display(file.columns)
# Out:
# Index(['Unnamed: 0', 'Customer', 'State', 'Customer Lifetime Value',
#        'Response', 'Coverage', 'Education', 'Effective To Date',
#        'EmploymentStatus', 'Gender', 'Income', 'Location Code',
#        'Marital Status', 'Monthly Premium Auto', 'Months Since Last Claim',
#        'Months Since Policy Inception', 'Number of Open Complaints',
#        'Number of Policies', 'Policy Type', 'Policy', 'Renew Offer Type',
#        'Sales Channel', 'Total Claim Amount', 'Vehicle Class', 'Vehicle Size',
#        'Vehicle Type'],
#       dtype='object')

# %%
file = file.drop(['Unnamed: 0'], axis=1)  #droping the column that repet itself
display(file.columns)
file
# Out:
# Index(['Customer', 'State', 'Customer Lifetime Value', 'Response', 'Coverage',
#        'Education', 'Effective To Date', 'EmploymentStatus', 'Gender',
#        'Income', 'Location Code', 'Marital Status', 'Monthly Premium Auto',
#        'Months Since Last Claim', 'Months Since Policy Inception',
#        'Number of Open Complaints', 'Number of Policies', 'Policy Type',
#        'Policy', 'Renew Offer Type', 'Sales Channel', 'Total Claim Amount',
#        'Vehicle Class', 'Vehicle Size', 'Vehicle Type'],
#       dtype='object')
#       Customer       State  Customer Lifetime Value Response  Coverage  \
# 0      DK49336     Arizona              4809.216960       No     Basic
# 1      KX64629  California              2228.525238       No     Basic
# 2      LZ68649  Washington             14947.917300       No     Basic
# 3      XL78013      Oregon             22332.439460      Yes  Extended
# 4      QA50777      Oregon              9025.067525       No   Premium
# ...

# %%
file
file.dtypes
file._get_numeric_data()
#file._get_categorical_data()
#file.select_dtypes(['objects'])
# Out:
#        Customer Lifetime Value  Income  Monthly Premium Auto  \
# 0                  4809.216960   48029                    61
# 1                  2228.525238       0                    64
# 2                 14947.917300   22139                   100
# 3                 22332.439460   49078                    97
# 4                  9025.067525   23675                   117
# ...                        ...     ...                   ...
# 10905             15563.369440       0                   253
# 10906              5259.444853   61146                    65
# 10907             23893.304100   39837                   201
# 10908             11971.977650   64195                   158
# 10909              6857.519928       0                   101
#
#        Months Since Last Claim  Months Since Policy Inception  \
# 0                          7.0                             52
# 1                          3.0                             26
# ...

# %%
file.select_dtypes("object")
# Out:
#       Customer       State Response  Coverage Education Effective To Date  \
# 0      DK49336     Arizona       No     Basic   College           2/18/11
# 1      KX64629  California       No     Basic   College           1/18/11
# 2      LZ68649  Washington       No     Basic  Bachelor           2/10/11
# 3      XL78013      Oregon      Yes  Extended   College           1/11/11
# 4      QA50777      Oregon       No   Premium  Bachelor           1/17/11
# ...        ...         ...      ...       ...       ...               ...
# 10905  FE99816      Nevada       No   Premium  Bachelor           1/19/11
# 10906  KX53892      Oregon       No     Basic   College            1/6/11
# 10907  TL39050     Arizona       No  Extended  Bachelor            2/6/11
# 10908  WA60547  California       No   Premium   College           2/13/11
# 10909  IV32877         NaN      NaN     Basic  Bachelor            1/8/11
#
#       EmploymentStatus Gender Location Code Marital Status     Policy Type  \
# ...

# %%
file.isna().sum()
# Out:
# Customer                            0
# State                             631
# Customer Lifetime Value             0
# Response                          631
# Coverage                            0
# Education                           0
# Effective To Date                   0
# EmploymentStatus                    0
# Gender                              0
# Income                              0
# Location Code                       0
# Marital Status                      0
# Monthly Premium Auto                0
# Months Since Last Claim           633
# Months Since Policy Inception       0
# Number of Open Complaints         633
# Number of Policies                  0
# Policy Type                         0
# Policy                              0
# Renew Offer Type                    0
# Sales Channel                       0
# Total Claim Amount                  0
# Vehicle Class                     622
# Vehicle Size                      622
# Vehicle Type                     5482
# ...

# %%
print(file['Response'].unique())
print(file['Response'].value_counts())
# Out:
# ['No' 'Yes' nan]
# No     8813
# Yes    1466
# Name: Response, dtype: int64

# %%
round(file.isna().sum()/len(file),4)*100  # shows the percentage of null values in a column
nulls_file = pd.DataFrame(round(file.isna().sum()/len(file),4)*100)
nulls_file
# Out:
#                                    0
# Customer                        0.00
# State                           5.78
# Customer Lifetime Value         0.00
# Response                        5.78
# Coverage                        0.00
# Education                       0.00
# Effective To Date               0.00
# EmploymentStatus                0.00
# Gender                          0.00
# Income                          0.00
# Location Code                   0.00
# Marital Status                  0.00
# Monthly Premium Auto            0.00
# Months Since Last Claim         5.80
# Months Since Policy Inception   0.00
# Number of Open Complaints       5.80
# Number of Policies              0.00
# Policy Type                     0.00
# Policy                          0.00
# Renew Offer Type                0.00
# Sales Channel                   0.00
# Total Claim Amount              0.00
# Vehicle Class                   5.70
# Vehicle Size                    5.70
# ...

# %%
file["State"].value_counts(dropna=False)
# Out:
# California    3552
# Oregon        2909
# Arizona       1937
# Nevada         993
# Washington     888
# NaN            631
# Name: State, dtype: int64

# %%
file["Vehicle Type"].value_counts(dropna=False)
# Out:
# NaN    5482
# A      5428
# Name: Vehicle Type, dtype: int64

# %%
file['Vehicle Type'] = file['Vehicle Type'].fillna('not A') #assighning the NAN values to 'not a' 
#because there is a lot of information i dont want to lose
len(file[file['Vehicle Type'].isna()==True]) # now this number is 0
# Out:
# 0

# %%
file["Response"].value_counts(dropna=False)
# Out:
# No     8813
# Yes    1466
# NaN     631
# Name: Response, dtype: int64

# %%
#file = file.drop(['State'], axis=1)
file
# Out:
#       Customer       State  Customer Lifetime Value Response  Coverage  \
# 0      DK49336     Arizona              4809.216960       No     Basic
# 1      KX64629  California              2228.525238       No     Basic
# 2      LZ68649  Washington             14947.917300       No     Basic
# 3      XL78013      Oregon             22332.439460      Yes  Extended
# 4      QA50777      Oregon              9025.067525       No   Premium
# ...        ...         ...                      ...      ...       ...
# 10905  FE99816      Nevada             15563.369440       No   Premium
# 10906  KX53892      Oregon              5259.444853       No     Basic
# 10907  TL39050     Arizona             23893.304100       No  Extended
# 10908  WA60547  California             11971.977650       No   Premium
# 10909  IV32877         NaN              6857.519928      NaN     Basic
#
#       Education Effective To Date EmploymentStatus Gender  Income  ...  \
# ...

# %%
file
# Out:
#       Customer       State  Customer Lifetime Value Response  Coverage  \
# 0      DK49336     Arizona              4809.216960       No     Basic
# 1      KX64629  California              2228.525238       No     Basic
# 2      LZ68649  Washington             14947.917300       No     Basic
# 3      XL78013      Oregon             22332.439460      Yes  Extended
# 4      QA50777      Oregon              9025.067525       No   Premium
# ...        ...         ...                      ...      ...       ...
# 10905  FE99816      Nevada             15563.369440       No   Premium
# 10906  KX53892      Oregon              5259.444853       No     Basic
# 10907  TL39050     Arizona             23893.304100       No  Extended
# 10908  WA60547  California             11971.977650       No   Premium
# 10909  IV32877         NaN              6857.519928      NaN     Basic
#
#       Education Effective To Date EmploymentStatus Gender  Income  ...  \
# ...

# %%
file.isna().sum()
# Out:
# Customer                           0
# State                            631
# Customer Lifetime Value            0
# Response                         631
# Coverage                           0
# Education                          0
# Effective To Date                  0
# EmploymentStatus                   0
# Gender                             0
# Income                             0
# Location Code                      0
# Marital Status                     0
# Monthly Premium Auto               0
# Months Since Last Claim          633
# Months Since Policy Inception      0
# Number of Open Complaints        633
# Number of Policies                 0
# Policy Type                        0
# Policy                             0
# Renew Offer Type                   0
# Sales Channel                      0
# Total Claim Amount                 0
# Vehicle Class                    622
# Vehicle Size                     622
# Vehicle Type                       0
# dtype: int64

# %%
file = file[file['State'].isna()==False] #droping what i can give up on
#and will also delete NAN values from other columns

# %%
file.isna().sum()
# Out:
# Customer                           0
# State                              0
# Customer Lifetime Value            0
# Response                           0
# Coverage                           0
# Education                          0
# Effective To Date                  0
# EmploymentStatus                   0
# Gender                             0
# Income                             0
# Location Code                      0
# Marital Status                     0
# Monthly Premium Auto               0
# Months Since Last Claim          591
# Months Since Policy Inception      0
# Number of Open Complaints        591
# Number of Policies                 0
# Policy Type                        0
# Policy                             0
# Renew Offer Type                   0
# Sales Channel                      0
# Total Claim Amount                 0
# Vehicle Class                    591
# Vehicle Size                     591
# Vehicle Type                       0
# dtype: int64

# %%
file = file[file['Vehicle Class'].isna()==False] #droping what i can give up on
file.isna().sum()
# Out:
# Customer                           0
# State                              0
# Customer Lifetime Value            0
# Response                           0
# Coverage                           0
# Education                          0
# Effective To Date                  0
# EmploymentStatus                   0
# Gender                             0
# Income                             0
# Location Code                      0
# Marital Status                     0
# Monthly Premium Auto               0
# Months Since Last Claim          554
# Months Since Policy Inception      0
# Number of Open Complaints        554
# Number of Policies                 0
# Policy Type                        0
# Policy                             0
# Renew Offer Type                   0
# Sales Channel                      0
# Total Claim Amount                 0
# Vehicle Class                      0
# Vehicle Size                       0
# Vehicle Type                       0
# dtype: int64

# %%
file = file[file['Months Since Last Claim'].isna()==False] #droping what i can give up on
file.isna().sum()
# Out:
# Customer                         0
# State                            0
# Customer Lifetime Value          0
# Response                         0
# Coverage                         0
# Education                        0
# Effective To Date                0
# EmploymentStatus                 0
# Gender                           0
# Income                           0
# Location Code                    0
# Marital Status                   0
# Monthly Premium Auto             0
# Months Since Last Claim          0
# Months Since Policy Inception    0
# Number of Open Complaints        0
# Number of Policies               0
# Policy Type                      0
# Policy                           0
# Renew Offer Type                 0
# Sales Channel                    0
# Total Claim Amount               0
# Vehicle Class                    0
# Vehicle Size                     0
# Vehicle Type                     0
# dtype: int64

# %%
import time
from datetime import date

today = date.today()
today
# Out:
# datetime.date(2022, 6, 16)

# %%
file['Effective To Date']=pd.to_datetime(file['Effective To Date'])
file.dtypes
# Out:
# Customer                                 object
# State                                    object
# Customer Lifetime Value                 float64
# Response                                 object
# Coverage                                 object
# Education                                object
# Effective To Date                datetime64[ns]
# EmploymentStatus                         object
# Gender                                   object
# Income                                    int64
# Location Code                            object
# Marital Status                           object
# Monthly Premium Auto                      int64
# Months Since Last Claim                 float64
# Months Since Policy Inception             int64
# Number of Open Complaints               float64
# Number of Policies                        int64
# Policy Type                              object
# Policy                                   object
# Renew Offer Type                         object
# ...

# %%
file
# Out:
#       Customer       State  Customer Lifetime Value Response  Coverage  \
# 0      DK49336     Arizona              4809.216960       No     Basic
# 1      KX64629  California              2228.525238       No     Basic
# 2      LZ68649  Washington             14947.917300       No     Basic
# 3      XL78013      Oregon             22332.439460      Yes  Extended
# 6      IW72280  California              5035.035257       No     Basic
# ...        ...         ...                      ...      ...       ...
# 10903  SU71163     Arizona              2771.663013       No     Basic
# 10904  QI63521      Nevada             19228.463620       No     Basic
# 10906  KX53892      Oregon              5259.444853       No     Basic
# 10907  TL39050     Arizona             23893.304100       No  Extended
# 10908  WA60547  California             11971.977650       No   Premium
#
#                   Education Effective To Date EmploymentStatus Gender  Income  \
# ...

# %%
file['Effective To Date Month'] = file['Effective To Date'].dt.month

# %%
file
file.dtypes
# Out:
# Customer                                 object
# State                                    object
# Customer Lifetime Value                 float64
# Response                                 object
# Coverage                                 object
# Education                                object
# Effective To Date                datetime64[ns]
# EmploymentStatus                         object
# Gender                                   object
# Income                                    int64
# Location Code                            object
# Marital Status                           object
# Monthly Premium Auto                      int64
# Months Since Last Claim                 float64
# Months Since Policy Inception             int64
# Number of Open Complaints               float64
# Number of Policies                        int64
# Policy Type                              object
# Policy                                   object
# Renew Offer Type                         object
# ...

# %%
file[file['Effective To Date Month'].isin([1, 2, 3])]
# Out:
#       Customer       State  Customer Lifetime Value Response  Coverage  \
# 0      DK49336     Arizona              4809.216960       No     Basic
# 1      KX64629  California              2228.525238       No     Basic
# 2      LZ68649  Washington             14947.917300       No     Basic
# 3      XL78013      Oregon             22332.439460      Yes  Extended
# 6      IW72280  California              5035.035257       No     Basic
# ...        ...         ...                      ...      ...       ...
# 10903  SU71163     Arizona              2771.663013       No     Basic
# 10904  QI63521      Nevada             19228.463620       No     Basic
# 10906  KX53892      Oregon              5259.444853       No     Basic
# 10907  TL39050     Arizona             23893.304100       No  Extended
# 10908  WA60547  California             11971.977650       No   Premium
#
#                   Education Effective To Date EmploymentStatus Gender  Income  \
# ...

# %%
def clean(file):
    file = file.drop(['Unnamed: 0'], axis=1) #1
    file['State'].value_counts(dropna=False) #2
    file['Vehicle Type'] = file['Vehicle Type'].fillna('not A') #4
    file['Vehicle Type'].value_counts(dropna=False) #5
    file = file[file['State'].isna()==False] #7
    file = file[file['Months Since Last Claim'].isna()==False] #8
    file = file[file['Vehicle Class'].isna()==False] #9
    file['Effective To Date'] = pd.to_datetime(file['Effective To Date']) #10
    file['Effective To Date Month'] = file['Effective To Date'].dt.month #11
    file[file['Effective To Date Month'].isin([1, 2, 3])] #12
    columns = [] #13
    for i in file.columns:
        columns.append(i.lower())
    file.columns = columns
    return file
file.dtypes
# Out:
# Customer                                 object
# State                                    object
# Customer Lifetime Value                 float64
# Response                                 object
# Coverage                                 object
# Education                                object
# Effective To Date                datetime64[ns]
# EmploymentStatus                         object
# Gender                                   object
# Income                                    int64
# Location Code                            object
# Marital Status                           object
# Monthly Premium Auto                      int64
# Months Since Last Claim                 float64
# Months Since Policy Inception             int64
# Number of Open Complaints               float64
# Number of Policies                        int64
# Policy Type                              object
# Policy                                   object
# Renew Offer Type                         object
# ...

# %%
######## lesson 3

# %%
df = pd.DataFrame(file)
display(file)
file.dtypes
# Out:
#       Customer       State  Customer Lifetime Value Response  Coverage  \
# 0      DK49336     Arizona              4809.216960       No     Basic
# 1      KX64629  California              2228.525238       No     Basic
# 2      LZ68649  Washington             14947.917300       No     Basic
# 3      XL78013      Oregon             22332.439460      Yes  Extended
# 6      IW72280  California              5035.035257       No     Basic
# ...        ...         ...                      ...      ...       ...
# 10903  SU71163     Arizona              2771.663013       No     Basic
# 10904  QI63521      Nevada             19228.463620       No     Basic
# 10906  KX53892      Oregon              5259.444853       No     Basic
# 10907  TL39050     Arizona             23893.304100       No  Extended
# 10908  WA60547  California             11971.977650       No   Premium
#
#                   Education Effective To Date EmploymentStatus Gender  Income  \
# ...

# %%
file.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 9134 entries, 0 to 10908
# Data columns (total 26 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   Customer                       9134 non-null   object
#  1   State                          9134 non-null   object
#  2   Customer Lifetime Value        9134 non-null   float64
#  3   Response                       9134 non-null   object
#  4   Coverage                       9134 non-null   object
#  5   Education                      9134 non-null   object
#  6   Effective To Date              9134 non-null   datetime64[ns]
#  7   EmploymentStatus               9134 non-null   object
#  8   Gender                         9134 non-null   object
#  9   Income                         9134 non-null   int64
#  10  Location Code                  9134 non-null   object
#  11  Marital Status                 9134 non-null   object
# ...

# %%
file.describe(include='all').T
# Out:
# C:\Users\moshi\AppData\Local\Temp/ipykernel_18228/255635451.py:1: FutureWarning: Treating datetime data as categorical rather than numeric in `.describe` is deprecated and will be removed in a future version of pandas. Specify `datetime_is_numeric=True` to silence this warning and adopt the future behavior now.
#   file.describe(include='all').T
#                                 count unique                  top  freq  \
# Customer                         9134   9134              DK49336     1
# State                            9134      5           California  3150
# Customer Lifetime Value        9134.0    NaN                  NaN   NaN
# Response                         9134      2                   No  7826
# Coverage                         9134      3                Basic  5568
# Education                        9134      5             Bachelor  2748
# Effective To Date                9134     59  2011-01-10 00:00:00   195
# ...

# %%
# summary = file.describe().T
# summary['iqr'] = summary['75%']-summary['25%']
# summary['mean'] = list(map(lambda x: round(x,2), summary['mean']))

# for col in summary.columns:
#     summary[col] = summary[col].apply(lambda x : round(x, 2))
# summary

# %%
columns = [] 
for i in file.columns:
    columns.append(i.lower())
file.columns = columns
file.head()
file.dtypes
# Out:
# customer                                 object
# state                                    object
# customer lifetime value                 float64
# response                                 object
# coverage                                 object
# education                                object
# effective to date                datetime64[ns]
# employmentstatus                         object
# gender                                   object
# income                                    int64
# location code                            object
# marital status                           object
# monthly premium auto                      int64
# months since last claim                 float64
# months since policy inception             int64
# number of open complaints               float64
# number of policies                        int64
# policy type                              object
# policy                                   object
# renew offer type                         object
# ...

# %%
import matplotlib.pyplot as plt
import seaborn as sns #a visulizaton library
# %matplotlib inline

# %%
file['response'].value_counts()
# Out:
# No     7826
# Yes    1308
# Name: response, dtype: int64

# %%
sns.countplot(x=file["response"],data=file) # counting response
# Out:
# <AxesSubplot:xlabel='response', ylabel='count'>

# %%
file['sales channel'].value_counts() # counting all the sales channel rows
# Out:
# Agent          3477
# Branch         2567
# Call Center    1765
# Web            1325
# Name: sales channel, dtype: int64

# %%
#creating a new column called response rate by using np.where function to give a 1 where the value is 'yes' and 0 where 'no'
file['response_rate'] = np.where(file.response=='Yes',1,0)
file['response_rate'].value_counts()
# Out:
# 0    7826
# 1    1308
# Name: response_rate, dtype: int64

# %%
file.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 9134 entries, 0 to 10908
# Data columns (total 27 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   customer                       9134 non-null   object
#  1   state                          9134 non-null   object
#  2   customer lifetime value        9134 non-null   float64
#  3   response                       9134 non-null   object
#  4   coverage                       9134 non-null   object
#  5   education                      9134 non-null   object
#  6   effective to date              9134 non-null   datetime64[ns]
#  7   employmentstatus               9134 non-null   object
#  8   gender                         9134 non-null   object
#  9   income                         9134 non-null   int64
#  10  location code                  9134 non-null   object
#  11  marital status                 9134 non-null   object
# ...

# %%
# using sns barplot with x as sales channel and y as response rate and the bar is showing mean values of response rate
# for each sales channel
sns.barplot(y=file["response_rate"], x=file["sales channel"],data=file)
# Out:
# <AxesSubplot:xlabel='sales channel', ylabel='response_rate'>

# %%
# we first describe the total claim amount so we can get the different percentile values
file['total claim amount'].describe()
# Out:
# count    9134.000000
# mean      434.088794
# std       290.500092
# min         0.099007
# 25%       272.258244
# 50%       383.945434
# 75%       547.514839
# max      2893.239678
# Name: total claim amount, dtype: float64

# %%
# we use the describe values to create a function which will help put the row values in total claim amount to different bins
def c_bins(row):
    if row < 272:
        return ' < 25%'
    elif row < 383:
        return '25%-50%'
    elif row < 548:
        return '50%-75%'
    else:
        return '> 75%'
# go and get every row of total claim amount and apply the bins() function to every row
file['claim bin'] = file['total claim amount'].apply(lambda row: c_bins(row))
file.head()
# Out:
#   customer       state  customer lifetime value response  coverage education  \
# 0  DK49336     Arizona              4809.216960       No     Basic   College
# 1  KX64629  California              2228.525238       No     Basic   College
# 2  LZ68649  Washington             14947.917300       No     Basic  Bachelor
# 3  XL78013      Oregon             22332.439460      Yes  Extended   College
# 6  IW72280  California              5035.035257       No     Basic    Doctor
#
#   effective to date employmentstatus gender  income  ...        policy  \
# 0        2011-02-18         Employed      M   48029  ...  Corporate L3
# 1        2011-01-18       Unemployed      F       0  ...   Personal L3
# 2        2011-02-10         Employed      M   22139  ...   Personal L3
# 3        2011-01-11         Employed      M   49078  ...  Corporate L3
# 6        2011-02-14         Employed      F   37405  ...  Corporate L2
#
#   renew offer type  sales channel  total claim amount  vehicle class  \
# ...

# %%
sns.barplot(y=file["response_rate"], x=file["claim bin"],data=file)
# Out:
# <AxesSubplot:xlabel='claim bin', ylabel='response_rate'>

# %%
file['income'].describe()
# Out:
# count     9134.000000
# mean     37657.380009
# std      30379.904734
# min          0.000000
# 25%          0.000000
# 50%      33889.500000
# 75%      62320.000000
# max      99981.000000
# Name: income, dtype: float64

# %%
def i_bins(row):
    if row < 33890:
        return ' < 50%'
    elif row < 62320:
        return '50%-75%'
    else:
        return '>75%'

file['income bins'] = file['income'].apply(lambda row: i_bins(row))
file.head()
# Out:
#   customer       state  customer lifetime value response  coverage education  \
# 0  DK49336     Arizona              4809.216960       No     Basic   College
# 1  KX64629  California              2228.525238       No     Basic   College
# 2  LZ68649  Washington             14947.917300       No     Basic  Bachelor
# 3  XL78013      Oregon             22332.439460      Yes  Extended   College
# 6  IW72280  California              5035.035257       No     Basic    Doctor
#
#   effective to date employmentstatus gender  income  ... renew offer type  \
# 0        2011-02-18         Employed      M   48029  ...           Offer3
# 1        2011-01-18       Unemployed      F       0  ...           Offer4
# 2        2011-02-10         Employed      M   22139  ...           Offer3
# 3        2011-01-11         Employed      M   49078  ...           Offer2
# 6        2011-02-14         Employed      F   37405  ...           Offer2
#
# ...

# %%
#bar plot of response rate vs income bins

sns.barplot(y=file["response_rate"], x=file["income bins"],data=file)
# Out:
# <AxesSubplot:xlabel='income bins', ylabel='response_rate'>

# %%
### day 4

# %%
file['effective to date']=file['effective to date'].astype(str)

# %%
numerical = file.select_dtypes(include=np.number)
display(numerical.dtypes)
display(numerical.shape)
# Out:
# customer lifetime value          float64
# income                             int64
# monthly premium auto               int64
# months since last claim          float64
# months since policy inception      int64
# number of open complaints        float64
# number of policies                 int64
# total claim amount               float64
# effective to date month            int64
# response_rate                      int32
# dtype: object
# (9134, 10)

# %%
categorical = file.select_dtypes(include=np.object)
display(categorical.dtypes)
display(categorical.shape)
# Out:
# C:\Users\moshi\AppData\Local\Temp/ipykernel_18228/1119751964.py:1: DeprecationWarning: `np.object` is a deprecated alias for the builtin `object`. To silence this warning, use `object` by itself. Doing this will not modify any behavior and is safe.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   categorical = file.select_dtypes(include=np.object)
# customer             object
# state                object
# response             object
# coverage             object
# education            object
# effective to date    object
# employmentstatus     object
# gender               object
# location code        object
# marital status       object
# policy type          object
# policy               object
# renew offer type     object
# sales channel        object
# vehicle class        object
# vehicle size         object
# vehicle type         object
# claim bin            object
# ...

# %%
from sklearn import linear_model
from sklearn.metrics import mean_squared_error, r2_score

# %%
display(sns.displot(numerical['customer lifetime value'], bins = 20,kde = True))
display(sns.displot(numerical['income'], bins = 20,kde = True))
display(sns.displot(numerical['monthly premium auto'], bins = 20,kde = True))
display(sns.displot(numerical['months since last claim'], bins = 20,kde = True))
display(sns.displot(numerical['months since policy inception'], bins = 20,kde = True))
display(sns.displot(numerical['number of open complaints'], bins = 20,kde = True))
display(sns.displot(numerical['number of policies'], bins = 20,kde = True))
display(sns.displot(numerical['total claim amount'], bins = 20,kde = True))

# %%
file['customer lifetime value'].hist(bins=60)
plt.show()

# %%
file['income'].hist(bins=60)
plt.show()

# %%
file['monthly premium auto'].hist(bins=60)
plt.show()

# %%
file['months since last claim'].hist(bins=60)
plt.show()

# %%
file['months since policy inception'].hist(bins=60)
plt.show()

# %%
file['number of open complaints'].hist(bins=60)
plt.show()

# %%
file['number of policies'].hist(bins=60)
plt.show()

# %%
file['total claim amount'].hist(bins=60)
plt.show()

# %%
y = numerical['total claim amount']
X2 = numerical.drop(['total claim amount'], axis=1)
lm2 = linear_model.LinearRegression()
lm2.fit(X2,y)
print(lm2.score(X2,y))
y_pred = lm2.predict(X2)
print(mean_squared_error(y_pred,y))
# Out:
# 0.5188549060891647
# 40599.53505773373

# %%
# regression_line = lm2.intercept_ + lm2.coef_[0]*numerical['monthly premium auto']
# plt.plot(numerical['monthly premium auto'], regression_line, c = 'orange')
# sns.scatterplot(x='monthly premium auto',y='total claim amount',data=numerical)
# plt.show()

# %%
correlations_matrix = round(numerical.corr(),2)
sns.heatmap(correlations_matrix, annot=True)
plt.show()

# %%
## i didnt drop anything because i did not get a correlation of more than 0.9

# %%
### ROUND 5

# %%
sns.scatterplot(x='monthly premium auto',y='total claim amount',data=file)   #they are the most corrolated
plt.show()

# %%
file['monthly premium auto'].corr(file['total claim amount'])
# Out:
# 0.632016662519412

# %%
y = file['total claim amount']
X = file[['monthly premium auto']]

# %%
from sklearn import linear_model
from sklearn.metrics import mean_squared_error

lm = linear_model.LinearRegression()

# %%
lm.fit(X,y)
print(lm.intercept_)
print(lm.coef_)
# Out:
# -63.32929837275799
# [5.33599955]

# %%
#visualize result
regression_line = lm.intercept_ + lm.coef_[0]*file['monthly premium auto']
plt.plot(file['monthly premium auto'], regression_line, c = 'orange')
sns.scatterplot(x='monthly premium auto',y='total claim amount',data=numerical)
plt.show()

# %%
numerical['monthly premium auto'].describe()     #we dont have 0 values so im not apllying log function
# Out:
# count    9134.000000
# mean       93.219291
# std        34.407967
# min        61.000000
# 25%        68.000000
# 50%        83.000000
# 75%       109.000000
# max       298.000000
# Name: monthly premium auto, dtype: float64

# %%
iqr = np.percentile(numerical['monthly premium auto'],75) - np.percentile(numerical['monthly premium auto'],25)
upper_limit = np.percentile(numerical['monthly premium auto'],75) + 1.5*iqr
lower_limit = np.percentile(numerical['monthly premium auto'],25) - 1.5*iqr
data = numerical[(numerical['monthly premium auto']>lower_limit) & (numerical['monthly premium auto']<upper_limit)].copy()
sns.displot(data['monthly premium auto'])
plt.show()

# %%
from sklearn.preprocessing import MinMaxScaler
from sklearn.preprocessing import StandardScaler

y = file['monthly premium auto']
X = file.drop(['monthly premium auto'], axis=1)
X_num = X.select_dtypes(include = np.number)
X_cat = X.select_dtypes(include = object)

# %%
X_num
# Out:
#        customer lifetime value  income  months since last claim  \
# 0                  4809.216960   48029                      7.0
# 1                  2228.525238       0                      3.0
# 2                 14947.917300   22139                     34.0
# 3                 22332.439460   49078                     10.0
# 6                  5035.035257   37405                      8.0
# ...                        ...     ...                      ...
# 10903              2771.663013   59855                     30.0
# 10904             19228.463620       0                     14.0
# 10906              5259.444853   61146                      7.0
# 10907             23893.304100   39837                     11.0
# 10908             11971.977650   64195                      0.0
#
#        months since policy inception  number of open complaints  \
# 0                                 52                        0.0
# 1                                 26                        0.0
# ...

# %%
# Normalizing data: make data range from 0 - 1, instead of from min to max
transformer = MinMaxScaler().fit(X_num)
x_normalized = transformer.transform(X_num)
print(x_normalized.shape)
x_normalized
pd.DataFrame(x_normalized, columns=X_num.columns)
# Out:
# (9134, 9)
#       customer lifetime value    income  months since last claim  \
# 0                    0.035752  0.480381                 0.200000
# 1                    0.004059  0.000000                 0.085714
# 2                    0.160264  0.221432                 0.971429
# 3                    0.250953  0.490873                 0.285714
# 4                    0.038525  0.374121                 0.228571
# ...                       ...       ...                      ...
# 9129                 0.010729  0.598664                 0.857143
# 9130                 0.212833  0.000000                 0.400000
# 9131                 0.041281  0.611576                 0.200000
# 9132                 0.270122  0.398446                 0.314286
# 9133                 0.123717  0.642072                 0.000000
#
#       months since policy inception  number of open complaints  \
# 0                          0.525253                        0.0
# ...

# %%
# scaling standard scaler: make data distributed with mean=0 and std=1
transformer = StandardScaler().fit(X_num)
x_standardized = transformer.transform(X_num)
print(x_standardized.shape)
pd.DataFrame(x_standardized, columns=X_num.columns)
# Out:
# (9134, 9)
#       customer lifetime value    income  months since last claim  \
# 0                   -0.465131  0.341416                -0.803856
# 1                   -0.840745 -1.239617                -1.200968
# 2                    1.010536 -0.510839                 1.876656
# 3                    2.085337  0.375947                -0.506021
# 4                   -0.432263 -0.008308                -0.704577
# ...                       ...       ...                      ...
# 9129                -0.761692  0.730708                 1.479543
# 9130                 1.633560 -1.239617                -0.108908
# 9131                -0.399601  0.773205                -0.803856
# 9132                 2.312518  0.071749                -0.406743
# 9133                 0.577394  0.873573                -1.498803
#
#       months since policy inception  number of open complaints  \
# 0                          0.141031                  -0.422250
# ...
